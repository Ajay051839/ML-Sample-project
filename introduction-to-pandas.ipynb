# %%
import pandas as pd

# %%
#There are 2 main data types in Pandas::
series=pd.Series(["BMW","Toyota","Jaguar"])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2    Jaguar
# dtype: object

# %%
#Series is 1-dimentional data type

# %%
colours=pd.Series(["Red","White","Blue"])

# %%
colours
# Out:
# 0      Red
# 1    White
# 2     Blue
# dtype: object

# %%
#DataFrame = 2-dimensional

# %%
car=pd.DataFrame({"Car make":series ,"Colours":colours})
car
# Out:
#   Car make Colours
# 0      BMW     Red
# 1   Toyota   White
# 2   Jaguar    Blue

# %%
#Import Data
car_data=pd.read_csv("car-sales.csv")

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
#Exporting a DataFrame
car_data.to_csv("car-sales-import.csv")

# %%
#Importing data from URL::
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ##Describe Data

# %%
#Attribute::(attribute doesn't have the bracket)
car_data.dtypes
# Out:
# Unnamed: 0        int64
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_data.columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns=car_data.columns
car_columns
# Out:
# Index(['Unnamed: 0', 'Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_data.describe() #STATISTICAL INFO ABOUT THE DATA
# Out:
#        Unnamed: 0  Odometer (KM)      Doors
# count    10.00000      10.000000  10.000000
# mean      4.50000   78601.400000   4.000000
# std       3.02765   61983.471735   0.471405
# min       0.00000   11179.000000   3.000000
# 25%       2.25000   35836.250000   4.000000
# 50%       4.50000   57369.000000   4.000000
# 75%       6.75000   96384.500000   4.000000
# max       9.00000  213095.000000   5.000000

# %%
car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     10 non-null     int64
#  1   Make           10 non-null     object
#  2   Colour         10 non-null     object
#  3   Odometer (KM)  10 non-null     int64
#  4   Doors          10 non-null     int64
#  5   Price          10 non-null     object
# dtypes: int64(3), object(3)
# memory usage: 608.0+ bytes

# %%
numeric_columns = car_data.select_dtypes(include=[int, float])

# %%
car_data_mean = numeric_columns.mean()

# %%
print(car_data_mean)
# Out:
# Unnamed: 0           4.5
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices=pd.Series([1200000,500000,900000])
car_prices.mean()
# Out:
# 866666.6666666666

# %%
car_data.sum()
# Out:
# Unnamed: 0                                                      45
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_data["Doors"].sum()
# Out:
# 40

# %%
len(car_data)
# Out:
# 10

# %%
car_data["Doors"].abs()
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
car_data.boxplot() #Just exploring
# Out:
# <Axes: >

# %%
#.head() and .tail() :: displays top 5 and bottom 5 rows respectiely.
car_data.head()
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00

# %%
car_data.tail()
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors      Price
# 5           5  Toyota  Green          99213      4  $4,500.00
# 6           6   Honda   Blue          45698      4  $7,500.00
# 7           7   Honda   Blue          54738      4  $7,000.00
# 8           8  Toyota  White          60000      4  $6,250.00
# 9           9  Nissan  White          31600      4  $9,700.00

# %%
car_data.head(7) #displays top-7 rows
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00

# %%
# .loc and .iloc :: .loc prefers the index whereas .iloc prefers position(starts from 0)
animals=pd.Series(["cat","dog","panda","camel","bear"],index=[1,6,8,9,6])

# %%
animals
# Out:
# 1      cat
# 6      dog
# 8    panda
# 9    camel
# 6     bear
# dtype: object

# %%
animals.loc[9] #it is kind of key and value
# Out:
# 'camel'

# %%
animals.loc[6]
# Out:
# 6     dog
# 6    bear
# dtype: object

# %%
animals.iloc[1] #It returns element at 1st position starting from 0
# Out:
# 'dog'

# %%
animals.iloc[10]   #error because no 10 elements
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 animals.iloc[10]   #error because no 10 elements
#
# File C:\Python310\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\Python310\lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
animals.iloc[4]
# Out:
# 'bear'

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_data.iloc[4]
# Out:
# Unnamed: 0               4
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
car_data.loc[:3] #that is equivalent to .head(4)
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00

# %%
#To Select Column

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_data["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_data["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_data["Price"]
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
#car_data["Colour"] and car_data.Colour both are same only diff comes when column names contains space in that case . can't be used

# %%
car_data.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_data.Odometer (KM) #this is the case where . not works
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3952\3914362614.py in ?()
# ----> 1 car_data.Odometer (KM) #this is the case where . not works
#
# C:\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Odometer'

# %%
car_data[car_data["Make"]=="Toyota"] #Returns row with Make=Toyota
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors      Price
# 0           0  Toyota  White         150043      4  $4,000.00
# 2           2  Toyota   Blue          32549      3  $7,000.00
# 5           5  Toyota  Green          99213      4  $4,500.00
# 8           8  Toyota  White          60000      4  $6,250.00

# %%
car_data[car_data["Odometer (KM)"]>80000]
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors      Price
# 0           0  Toyota  White         150043      4  $4,000.00
# 1           1   Honda    Red          87899      4  $5,000.00
# 4           4  Nissan  White         213095      4  $3,500.00
# 5           5  Toyota  Green          99213      4  $4,500.00

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_data["Make"],car_data["Doors"]) #cross tab will make the group
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
car_data.groupby(["Make"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File C:\Python310\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File C:\Python310\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File C:\Python310\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
car_data.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Unnamed: 0  Odometer (KM)  Doors
# Make
# BMW       3.000000   11179.000000   5.00
# Honda     4.666667   62778.333333   4.00
# Nissan    6.500000  122347.500000   4.00
# Toyota    3.750000   85451.250000   3.75

# %%
car_data["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_data["Doors"].plot()
# Out:
# <Axes: >

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
# %matplotlib inline #magic command used in Jupyter notebooks to display matplotlib plots directly within the notebook. When this command is used, the plots appear inline, meaning within the notebook itself, directly below the code cell that produces them.
import matplotlib.pyplot as plt
car_data["Doors"].plot()
plt.show()
# Out:
# UsageError: unrecognized arguments: #magic command used in Jupyter notebooks to display matplotlib plots directly within the notebook. When this command is used, the plots appear inline, meaning within the notebook itself, directly below the code cell that produces them.

# %%
import matplotlib.pyplot as plt
car_data["Doors"].plot()
plt.show()

# %%
car_data["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_data["Price"].dtype
# Out:
# dtype('O')

# %%
car_data["Price"] = car_data["Price"].str.replace('[\$\,]|\.\d*', '', regex=True).astype(int)

# %%
car_data["Price"].plot()
# Out:
# <Axes: >

# %%
#Manipulating Data

# %%
car_data["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0           0  toyota  White         150043      4   4000
# 1           1   honda    Red          87899      4   5000
# 2           2  toyota   Blue          32549      3   7000
# 3           3     bmw  Black          11179      5  22000
# 4           4  nissan  White         213095      4   3500
# 5           5  toyota  Green          99213      4   4500
# 6           6   honda   Blue          45698      4   7500
# 7           7   honda   Blue          54738      4   7000
# 8           8  toyota  White          60000      4   6250
# 9           9  nissan  White          31600      4   9700

# %%
#Note: The lowercase change is not  reflecting so in pandas we need to assign the updated value.
car_data["Make"]=car_data["Make"].str.lower()

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0           0  toyota  White         150043      4   4000
# 1           1   honda    Red          87899      4   5000
# 2           2  toyota   Blue          32549      3   7000
# 3           3     bmw  Black          11179      5  22000
# 4           4  nissan  White         213095      4   3500
# 5           5  toyota  Green          99213      4   4500
# 6           6   honda   Blue          45698      4   7500
# 7           7   honda   Blue          54738      4   7000
# 8           8  toyota  White          60000      4   6250
# 9           9  nissan  White          31600      4   9700

# %%
car_sales_missing=pd.read_csv("car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043      4   $4,000.00
# 1           1   Honda    Red          87899      4   $5,000.00
# 2           2  Toyota   Blue          32549      3   $7,000.00
# 3           3     BMW  Black          11179      5  $22,000.00
# 4           4  Nissan  White         213095      4   $3,500.00
# 5           5  Toyota  Green          99213      4   $4,500.00
# 6           6   Honda   Blue          45698      4   $7,500.00
# 7           7   Honda   Blue          54738      4   $7,000.00
# 8           8  Toyota  White          60000      4   $6,250.00
# 9           9  Nissan  White          31600      4   $9,700.00

# %%
car_sales_missing["Doors"].

# %%
car_sales_missing.loc[2, "Doors"] = None
car_sales_missing.loc[4, "Doors"] = None

# %%
car_sales_missing
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043    4.0   $4,000.00
# 1           1   Honda    Red          87899    4.0   $5,000.00
# 2           2  Toyota   Blue          32549    NaN   $7,000.00
# 3           3     BMW  Black          11179    5.0  $22,000.00
# 4           4  Nissan  White         213095    NaN   $3,500.00
# 5           5  Toyota  Green          99213    4.0   $4,500.00
# 6           6   Honda   Blue          45698    4.0   $7,500.00
# 7           7   Honda   Blue          54738    4.0   $7,000.00
# 8           8  Toyota  White          60000    4.0   $6,250.00
# 9           9  Nissan  White          31600    4.0   $9,700.00

# %%
car_sales_missing.loc[3, "Odometer (KM)"] = None
car_sales_missing.loc[5, "Odometer (KM)"] = None

# %%
car_sales_missing
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors       Price
# 0           0  Toyota  White         150043    4.0   $4,000.00
# 1           1   Honda    Red          87899    4.0   $5,000.00
# 2           2  Toyota   Blue          32549    NaN   $7,000.00
# 3           3     BMW  Black          11179    5.0  $22,000.00
# 4           4  Nissan  White         213095    NaN   $3,500.00
# 5           5  Toyota  Green          99213    4.0   $4,500.00
# 6           6   Honda   Blue          45698    4.0   $7,500.00
# 7           7   Honda   Blue          54738    4.0   $7,000.00
# 8           8  Toyota  White          60000    4.0   $6,250.00
# 9           9  Nissan  White          31600    4.0   $9,700.00

# %%
car_sales_missing.rename(columns={"Odometer (KM)": "Odometer"}, inplace=True) #Renaming

# %%
car_sales_missing
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors       Price
# 0           0  Toyota  White    150043    4.0   $4,000.00
# 1           1   Honda    Red     87899    4.0   $5,000.00
# 2           2  Toyota   Blue     32549    NaN   $7,000.00
# 3           3     BMW  Black     11179    5.0  $22,000.00
# 4           4  Nissan  White    213095    NaN   $3,500.00
# 5           5  Toyota  Green     99213    4.0   $4,500.00
# 6           6   Honda   Blue     45698    4.0   $7,500.00
# 7           7   Honda   Blue     54738    4.0   $7,000.00
# 8           8  Toyota  White     60000    4.0   $6,250.00
# 9           9  Nissan  White     31600    4.0   $9,700.00

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 78601.4

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors       Price
# 0           0  Toyota  White    150043    4.0   $4,000.00
# 1           1   Honda    Red     87899    4.0   $5,000.00
# 2           2  Toyota   Blue     32549    NaN   $7,000.00
# 3           3     BMW  Black     11179    5.0  $22,000.00
# 4           4  Nissan  White    213095    NaN   $3,500.00
# 5           5  Toyota  Green     99213    4.0   $4,500.00
# 6           6   Honda   Blue     45698    4.0   $7,500.00
# 7           7   Honda   Blue     54738    4.0   $7,000.00
# 8           8  Toyota  White     60000    4.0   $6,250.00
# 9           9  Nissan  White     31600    4.0   $9,700.00

# %%
car_sales_missing.dropna() #Drop the missing data row
# Out:
#    Unnamed: 0    Make Colour  Odometer  Doors       Price
# 0           0  Toyota  White    150043    4.0   $4,000.00
# 1           1   Honda    Red     87899    4.0   $5,000.00
# 3           3     BMW  Black     11179    5.0  $22,000.00
# 5           5  Toyota  Green     99213    4.0   $4,500.00
# 6           6   Honda   Blue     45698    4.0   $7,500.00
# 7           7   Honda   Blue     54738    4.0   $7,000.00
# 8           8  Toyota  White     60000    4.0   $6,250.00
# 9           9  Nissan  White     31600    4.0   $9,700.00

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price
# 0           0  toyota  White         150043      4   4000
# 1           1   honda    Red          87899      4   5000
# 2           2  toyota   Blue          32549      3   7000
# 3           3     bmw  Black          11179      5  22000
# 4           4  nissan  White         213095      4   3500
# 5           5  toyota  Green          99213      4   4500
# 6           6   honda   Blue          45698      4   7500
# 7           7   honda   Blue          54738      4   7000
# 8           8  toyota  White          60000      4   6250
# 9           9  nissan  White          31600      4   9700

# %%
#Insert new Column::
seats_column=pd.Series(["5","5","5","5"])
car_data["Seats"]=seats_column

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats
# 0           0  toyota  White         150043      4   4000     5
# 1           1   honda    Red          87899      4   5000     5
# 2           2  toyota   Blue          32549      3   7000     5
# 3           3     bmw  Black          11179      5  22000     5
# 4           4  nissan  White         213095      4   3500   NaN
# 5           5  toyota  Green          99213      4   4500   NaN
# 6           6   honda   Blue          45698      4   7500   NaN
# 7           7   honda   Blue          54738      4   7000   NaN
# 8           8  toyota  White          60000      4   6250   NaN
# 9           9  nissan  White          31600      4   9700   NaN

# %%
car_data["Seats"].fillna(5,inplace=True)

# %%
car_logo=pd.Series(["L","A","K","N","M"])
car_data["Logo"]=car_logo
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo
# 0           0  toyota  White         150043      4   4000     5    L
# 1           1   honda    Red          87899      4   5000     5    A
# 2           2  toyota   Blue          32549      3   7000     5    K
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 5           5  toyota  Green          99213      4   4500     5  NaN
# 6           6   honda   Blue          45698      4   7500     5  NaN
# 7           7   honda   Blue          54738      4   7000     5  NaN
# 8           8  toyota  White          60000      4   6250     5  NaN
# 9           9  nissan  White          31600      4   9700     5  NaN

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo
# 0           0  toyota  White         150043      4   4000     5    L
# 1           1   honda    Red          87899      4   5000     5    A
# 2           2  toyota   Blue          32549      3   7000     5    K
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 5           5  toyota  Green          99213      4   4500     5  NaN
# 6           6   honda   Blue          45698      4   7500     5  NaN
# 7           7   honda   Blue          54738      4   7000     5  NaN
# 8           8  toyota  White          60000      4   6250     5  NaN
# 9           9  nissan  White          31600      4   9700     5  NaN

# %%
car_data["Logo"].fillna("H",inplace=True)
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo
# 0           0  toyota  White         150043      4   4000     5    L
# 1           1   honda    Red          87899      4   5000     5    A
# 2           2  toyota   Blue          32549      3   7000     5    K
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 5           5  toyota  Green          99213      4   4500     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 7           7   honda   Blue          54738      4   7000     5    H
# 8           8  toyota  White          60000      4   6250     5    H
# 9           9  nissan  White          31600      4   9700     5    H

# %%
#Column from python list--(For this length of list should be same of the dataframe)
fuel_economy=[3.3,6.7,8.9,7.0,9.8,5.7,8.1,6.5,8.0,6.6]
car_data["Fuel per 100 KM"]=fuel_economy
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 0           0  toyota  White         150043      4   4000     5    L
# 1           1   honda    Red          87899      4   5000     5    A
# 2           2  toyota   Blue          32549      3   7000     5    K
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 5           5  toyota  Green          99213      4   4500     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 7           7   honda   Blue          54738      4   7000     5    H
# 8           8  toyota  White          60000      4   6250     5    H
# 9           9  nissan  White          31600      4   9700     5    H
#
#    Fuel per 100 KM
# 0              3.3
# 1              6.7
# 2              8.9
# 3              7.0
# 4              9.8
# 5              5.7
# 6              8.1
# 7              6.5
# 8              8.0
# ...

# %%
#column with other columns
car_data["Total Fuels used"]=(car_data["Odometer (KM)"]/100)* car_data["Fuel per 100 KM"]
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 0           0  toyota  White         150043      4   4000     5    L
# 1           1   honda    Red          87899      4   5000     5    A
# 2           2  toyota   Blue          32549      3   7000     5    K
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 5           5  toyota  Green          99213      4   4500     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 7           7   honda   Blue          54738      4   7000     5    H
# 8           8  toyota  White          60000      4   6250     5    H
# 9           9  nissan  White          31600      4   9700     5    H
#
#    Fuel per 100 KM  Total Fuels used
# 0              3.3          4951.419
# 1              6.7          5889.233
# 2              8.9          2896.861
# 3              7.0           782.530
# ...

# %%
car_data["Wheels"]=4
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 0           0  toyota  White         150043      4   4000     5    L
# 1           1   honda    Red          87899      4   5000     5    A
# 2           2  toyota   Blue          32549      3   7000     5    K
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 5           5  toyota  Green          99213      4   4500     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 7           7   honda   Blue          54738      4   7000     5    H
# 8           8  toyota  White          60000      4   6250     5    H
# 9           9  nissan  White          31600      4   9700     5    H
#
#    Fuel per 100 KM  Total Fuels used  Wheels
# 0              3.3          4951.419       4
# 1              6.7          5889.233       4
# 2              8.9          2896.861       4
# ...

# %%
car_data["Launched"]="Yes"

# %%
car_data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 0           0  toyota  White         150043      4   4000     5    L
# 1           1   honda    Red          87899      4   5000     5    A
# 2           2  toyota   Blue          32549      3   7000     5    K
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 5           5  toyota  Green          99213      4   4500     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 7           7   honda   Blue          54738      4   7000     5    H
# 8           8  toyota  White          60000      4   6250     5    H
# 9           9  nissan  White          31600      4   9700     5    H
#
#    Fuel per 100 KM  Total Fuels used  Wheels Launched
# 0              3.3          4951.419       4      Yes
# 1              6.7          5889.233       4      Yes
# ...

# %%
#Randomizing the data: Needed for ML algorithms to get the better results--
car_data.sample(frac=1)  #frac 1 means applied on 100% data
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 1           1   honda    Red          87899      4   5000     5    A
# 4           4  nissan  White         213095      4   3500     5    M
# 3           3     bmw  Black          11179      5  22000     5    N
# 8           8  toyota  White          60000      4   6250     5    H
# 5           5  toyota  Green          99213      4   4500     5    H
# 2           2  toyota   Blue          32549      3   7000     5    K
# 0           0  toyota  White         150043      4   4000     5    L
# 9           9  nissan  White          31600      4   9700     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 7           7   honda   Blue          54738      4   7000     5    H
#
#    Fuel per 100 KM  Total Fuels used  Wheels Launched
# 1              6.7          5889.233       4      Yes
# 4              9.8         20883.310       4      Yes
# ...

# %%
car_data.sample(frac=0.5)
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 9           9  nissan  White          31600      4   9700     5    H
# 3           3     bmw  Black          11179      5  22000     5    N
# 7           7   honda   Blue          54738      4   7000     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 5           5  toyota  Green          99213      4   4500     5    H
#
#    Fuel per 100 KM  Total Fuels used  Wheels Launched
# 9              6.6          2085.600       4      Yes
# 3              7.0           782.530       4      Yes
# 7              6.5          3557.970       4      Yes
# 6              8.1          3701.538       4      Yes
# 5              5.7          5655.141       4      Yes

# %%
car_data_shuffled=car_data.sample(frac=1)

# %%
car_data_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 7           7   honda   Blue          54738      4   7000     5    H
# 1           1   honda    Red          87899      4   5000     5    A
# 0           0  toyota  White         150043      4   4000     5    L
# 8           8  toyota  White          60000      4   6250     5    H
# 9           9  nissan  White          31600      4   9700     5    H
# 6           6   honda   Blue          45698      4   7500     5    H
# 5           5  toyota  Green          99213      4   4500     5    H
# 3           3     bmw  Black          11179      5  22000     5    N
# 4           4  nissan  White         213095      4   3500     5    M
# 2           2  toyota   Blue          32549      3   7000     5    K
#
#    Fuel per 100 KM  Total Fuels used  Wheels Launched
# 7              6.5          3557.970       4      Yes
# 1              6.7          5889.233       4      Yes
# ...

# %%
#In real life we need to deal with millions of rows--
#Selecting 20% data::
car_data_shuffled.sample(frac=0.2)
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 7           7   honda   Blue          54738      4   7000     5    H
# 0           0  toyota  White         150043      4   4000     5    L
#
#    Fuel per 100 KM  Total Fuels used  Wheels Launched
# 7              6.5          3557.970       4      Yes
# 0              3.3          4951.419       4      Yes

# %%
car_data_shuffled["Odometer (KM)"]=car_data_shuffled["Odometer (KM)"].apply(lambda x: x/1.6)  #KM/1.6=miles

# %%
car_data_shuffled
# Out:
#    Unnamed: 0    Make Colour  Odometer (KM)  Doors  Price Seats Logo  \
# 7           7   honda   Blue      34211.250      4   7000     5    H
# 1           1   honda    Red      54936.875      4   5000     5    A
# 0           0  toyota  White      93776.875      4   4000     5    L
# 8           8  toyota  White      37500.000      4   6250     5    H
# 9           9  nissan  White      19750.000      4   9700     5    H
# 6           6   honda   Blue      28561.250      4   7500     5    H
# 5           5  toyota  Green      62008.125      4   4500     5    H
# 3           3     bmw  Black       6986.875      5  22000     5    N
# 4           4  nissan  White     133184.375      4   3500     5    M
# 2           2  toyota   Blue      20343.125      3   7000     5    K
#
#    Fuel per 100 KM  Total Fuels used  Wheels Launched
# 7              6.5          3557.970       4      Yes
# 1              6.7          5889.233       4      Yes
# ...
